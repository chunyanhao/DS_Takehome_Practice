# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. Load data

# %% [markdown]
# In order to calculate the 'walking distance between employee homes and the closest bus stop', I decide first extract the Latitude and Longitude of the employee homes and bus stop using Google sheet and the add-ons 'Geocode by Awesome Table'.
#
# Refer to the instruction :https://www.youtube.com/watch?v=ozjSCoJGgVc

# %%
stops = pd.read_csv('/Users/ChunyanHao/desktop/github/ds_take_home/data/Bus/Bus_Stops_with_geocode.csv')
addresses = pd.read_csv('/Users/ChunyanHao/desktop/github/ds_take_home/data/Bus/address_with_geocode.csv')

# %%
stops.head(3)
# Out:
#    Street_One         Street_Two   Latitude   Longitude
# 0  MISSION ST          ITALY AVE  37.718478 -122.439536
# 1  MISSION ST  NEW MONTGOMERY ST  37.787456 -122.400523
# 2  MISSION ST            01ST ST  37.789768 -122.397597

# %%
stops.columns = ['Street_One', 'Street_Two', 'Stop_Lat', 'Stop_Long']

# %%
stops.shape
# Out:
# (119, 4)

# %%
#Remove bus stops with same Latitude and  Longitude, no need to stop the same location mulitple times
stops = stops.drop_duplicates(subset= ['Stop_Lat', 'Stop_Long'], keep="first")

# %%
stops.shape
# Out:
# (118, 4)

# %%
addresses.head(3)
# Out:
#                                          address   Latitude   Longitude  \
# 0  98 Edinburgh St, San Francisco, CA 94112, USA  37.728470 -122.426581
# 1       237 Accacia St, Daly City, CA 94014, USA  37.704205 -122.415878
# 2   1835 Folsom St, San Francisco, CA 94103, USA  37.767932 -122.415181
#
#    employee_id
# 0          206
# 1         2081
# 2          178

# %%
addresses.columns = ['address', 'Home_Lat', 'Home_Long', 'employee_id']

# %%
addresses.shape
# Out:
# (2191, 4)

# %% [markdown]
# ### 2. Calculate walking distance between employee address and each bus stop

# %%
# Prepare dataset to calculate the distance between each home address and bus stop
data = pd.merge(left = addresses, right = stops, how = 'cross' )

# %% [markdown]
# In order to calculat the distance between two location, I use Haversine Distance.
#
# Refer to the instruction: https://towardsdatascience.com/calculating-distance-between-two-geolocations-in-python-26ad3afe287b

# %%
import haversine as hs

def distance(row):
    loc1=(row[1],row[2])
    loc2=(row[6],row[7])
    return hs.haversine(loc1,loc2)
distance_column = []
for i in range(len(data)):
    row = data.iloc[i, :]
    distance_column.append(distance(row))
data['distance'] = distance_column

# %%
data.head(3)
# Out:
#                                          address  Home_Lat   Home_Long  \
# 0  98 Edinburgh St, San Francisco, CA 94112, USA  37.72847 -122.426581
# 1  98 Edinburgh St, San Francisco, CA 94112, USA  37.72847 -122.426581
# 2  98 Edinburgh St, San Francisco, CA 94112, USA  37.72847 -122.426581
#
#    employee_id  Street_One         Street_Two   Stop_Lat   Stop_Long  distance
# 0          206  MISSION ST          ITALY AVE  37.718478 -122.439536  1.591478
# 1          206  MISSION ST  NEW MONTGOMERY ST  37.787456 -122.400523  6.947443
# 2          206  MISSION ST            01ST ST  37.789768 -122.397597  7.276710

# %% [markdown]
# ### 3. Get the closest bus stop for each stop

# %%
closest_stop = data.groupby(['employee_id', 'address'])['distance'].agg('min').reset_index(name = 'distance')
closest_stop = pd.merge(left = closest_stop, 
                  right = data[['employee_id', 'distance', 'Street_One', 'Street_Two', 'Stop_Lat', 'Stop_Long']], 
                  how = 'inner', 
                  left_on = ['employee_id', 'distance'], 
                  right_on = ['employee_id', 'distance'])
closest_stop.head(5)
# Out:
#    employee_id                                       address  distance  \
# 0            1   220 Surrey St, San Francisco, CA 94131, USA  0.785148
# 1            2   110 Madrid St, San Francisco, CA 94112, USA  0.269820
# 2            3  1224 Athens St, San Francisco, CA 94112, USA  0.587206
# 3            4      171 Accacia St, Daly City, CA 94014, USA  2.563807
# 4            5   98 Brosnan St, San Francisco, CA 94103, USA  0.388062
#
#    Street_One        Street_Two   Stop_Lat   Stop_Long
# 0  MISSION ST       TRUMBULL ST  37.730891 -122.429259
# 1  MISSION ST  CASTLE MANOR AVE  37.729231 -122.430845
# 2  MISSION ST           POPE ST  37.715446 -122.441834
# 3  MISSION ST        SENECA AVE  37.717675 -122.440149
# 4  MISSION ST           ERIE ST  37.769063 -122.420072

# %%
closest_stop.shape
# Out:
# (2191, 7)

# %% [markdown]
# ### 4. Get the top 10 popular bus stops

# %%
result = closest_stop.groupby(['Street_One', 'Street_Two', 'Stop_Lat', 'Stop_Long'])['employee_id'].count().reset_index(name = 'employee_count')
result = result.sort_values(by = 'employee_count', ascending = False )[:10]
result
# Out:
#     Street_One   Street_Two   Stop_Lat   Stop_Long  employee_count
# 86  MISSION ST  TRUMBULL ST  37.730891 -122.429259             121
# 9   MISSION ST      15TH ST  37.766680 -122.419854             116
# 6   MISSION ST      12TH ST  37.773067 -122.418720             110
# 10  MISSION ST      16TH ST  37.765057 -122.419698             102
# 44  MISSION ST   GENEVA AVE  37.716494 -122.441022              79
# 37  MISSION ST      ERIE ST  37.769063 -122.420072              70
# 26  MISSION ST  BOSWORTH ST  37.733685 -122.426396              64
# 8   MISSION ST      14TH ST  37.768284 -122.420007              64
# 4   MISSION ST      10TH ST  37.775288 -122.415944              59
# 18  MISSION ST  ADMIRAL AVE  37.729844 -122.430177              49

# %%
street_map = plt.imread('/Users/ChunyanHao/desktop/github/ds_take_home/data/Bus/map.png')

# %%
BBox = (-122.4600, -122.3800, 37.69, 37.8)

# %%
fig, ax = plt.subplots(figsize = (16,14))
ax.scatter(addresses.Home_Long, addresses.Home_Lat, zorder=1, alpha= 0.5, c='r', s=10)
ax.scatter(result.Stop_Long, result.Stop_Lat, zorder=1, alpha= 1, c='b', s=15)
ax.set_title('Home Address and Bus Stops')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(street_map, zorder=0, extent = BBox, aspect= 'equal')
